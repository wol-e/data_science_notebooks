# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df_titles = pd.read_csv(
    "./data/movie_titles.csv",
    names=["id", "release", "title"],
    header=None, error_bad_lines=False, warn_bad_lines=True)

# %%
df_titles
# Out:
#           id  release                                              title
# 0          1   2003.0                                    Dinosaur Planet
# 1          2   2004.0                         Isle of Man TT 2004 Review
# 2          3   1997.0                                          Character
# 3          4   1994.0                       Paula Abdul's Get Up & Dance
# 4          5   2004.0                           The Rise and Fall of ECW
# ...      ...      ...                                                ...
# 17765  17766   2002.0  Where the Wild Things Are and Other Maurice Se...
# 17766  17767   2004.0                  Fidel Castro: American Experience
# 17767  17768   2000.0                                              Epoch
# 17768  17769   2003.0                                        The Company
# 17769  17770   2003.0                                       Alien Hunter
#
# [17770 rows x 3 columns]

# %%
"""There are some parsing errors, e.g. Id 72 is actually titles 
'At Home Among Strangers, A Stranger Among His Own', the comma in the title breaks it
"""
df_titles.iloc[70:74, :]
# Out:
#     id  release                                           title
# 70  71   1995.0                 Maya Lin: A Strong Clear Vision
# 71  72   1974.0                         At Home Among Strangers
# 72  73   1954.0  Davy Crockett: 50th Anniversary Double Feature
# 73  74   1999.0                                       6ixtynin9

# %%
plt.hist(df_titles.release, bins=100)

plt.show()

# %%
""""""

# %%
"""Does it include some of my favourite movies?"""

my_movies = [
    "The Godfather",
    "2001: A Space Odyssey",
    "Apocalypse Now",
    "Eternal Sunshine of the Spotless Mind",
    "Princess Mononoke",
    "The Shining",
    "Heat",
    "Lost in Translation"
]

df_titles[df_titles["title"].isin(my_movies)]
# Out:
#           id  release                                  title
# 472      473   1997.0                      Princess Mononoke
# 1864    1865   2004.0  Eternal Sunshine of the Spotless Mind
# 3289    3290   1974.0                          The Godfather
# 5777    5778   1990.0                          The Godfather
# 6098    6099   1979.0                         Apocalypse Now
# 6478    6479   1972.0                                   Heat
# 9888    9889   1987.0                                   Heat
# 11164  11165   1968.0                  2001: A Space Odyssey
# 12033  12034   1980.0                            The Shining
# 12231  12232   2003.0                    Lost in Translation
# 12292  12293   1972.0                          The Godfather
